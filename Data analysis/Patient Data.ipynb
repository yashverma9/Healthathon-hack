# %%
import pandas as pd
import numpy as np
import json

# %%
with open('careContext1.json') as f:
  data = json.load(f)

# %%
print(data.keys())
# Out:
# dict_keys(['content', 'media', 'careContextReference'])

# %%
print(data)
# Out:
# {'content': '[{"resourceType": "Bundle", "timestamp": "2020-11-04T08:08:43.298", "meta": {"profile": ["https://nrces.in/ndhm/fhir/r4/StructureDefinition/DocumentBundle"], "versionId": "1", "security": [{"code": "V", "system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "display": "very restricted"}], "lastUpdated": "2020-11-04T08:08:43.298"}, "entry": [{"resource": {"telecom": [{"use": "MOBILE", "system": "phone", "value": "7845245142"}], "meta": {"profile": ["https://nrces.in/ndhm/fhir/r4/StructureDefinition/Patient"], "versionId": "1", "lastUpdated": "2020-10-16T10:35:28Z"}, "name": [{"text": "Testing 8"}], "gender": "male", "resourceType": "Patient", "text": {"status": "generated", "div": "Testing 8"}, "identifier": [{"type": {"coding": [{"code": "", "system": "http://terminology.hl7.org/CodeSystem/v2-0203", "display": 2625}]}, "system": "", "value": ""}], "id": 20778513, "birthDate": null}, "fullUrl": "Patient/1"}, {"resource": {"name": [{"text": "Pratik"}], "reso
# ...

# %%
file1 = open("cleanedRes.txt","a") 
file1.write(str(data))
file1.close()

# %%
content = json.loads(data['content'])
print(type(content))
print(len(content))
# Out:
# <class 'list'>
# 4

# %%
for a in content:
    print(type(a))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
content[0]
# Out:
# {'resourceType': 'Bundle',
#  'timestamp': '2020-11-04T08:08:43.298',
#  'meta': {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/DocumentBundle'],
#   'versionId': '1',
#   'security': [{'code': 'V',
#     'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#     'display': 'very restricted'}],
#   'lastUpdated': '2020-11-04T08:08:43.298'},
#  'entry': [{'resource': {'telecom': [{'use': 'MOBILE',
#       'system': 'phone',
#       'value': '7845245142'}],
#     'meta': {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/Patient'],
#      'versionId': '1',
#      'lastUpdated': '2020-10-16T10:35:28Z'},
#     'name': [{'text': 'Testing 8'}],
#     'gender': 'male',
#     'resourceType': 'Patient',
#     'text': {'status': 'generated', 'div': 'Testing 8'},
#     'identifier': [{'type': {'coding': [{'code': '',
#          'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#          'display': 2625}]},
#       'system': '',
# ...

# %%
content[0].keys()
# Out:
# dict_keys(['resourceType', 'timestamp', 'meta', 'entry', 'identifier', 'type', 'id'])

# %%
content[0]['entry']
# Out:
# [{'resource': {'telecom': [{'use': 'MOBILE',
#      'system': 'phone',
#      'value': '7845245142'}],
#    'meta': {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/Patient'],
#     'versionId': '1',
#     'lastUpdated': '2020-10-16T10:35:28Z'},
#    'name': [{'text': 'Testing 8'}],
#    'gender': 'male',
#    'resourceType': 'Patient',
#    'text': {'status': 'generated', 'div': 'Testing 8'},
#    'identifier': [{'type': {'coding': [{'code': '',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'display': 2625}]},
#      'system': '',
#      'value': ''}],
#    'id': 20778513,
#    'birthDate': None},
#   'fullUrl': 'Patient/1'},
#  {'resource': {'name': [{'text': 'Pratik'}],
#    'resourceType': 'Practitioner',
#    'text': {'status': 'generated', 'div': 'Pratik'},
#    'meta': {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/Practitioner'],
#     'versionId': '1',
#     'lastUpdated': '2020-11-04T08:08:43.307'},
# ...

# %%
content[0]['resourceType']
# Out:
# 'Bundle'

# %%
content[0]['meta']
# Out:
# {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/DocumentBundle'],
#  'versionId': '1',
#  'security': [{'code': 'V',
#    'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#    'display': 'very restricted'}],
#  'lastUpdated': '2020-11-04T08:08:43.298'}

# %%
content[0]['timestamp']
# Out:
# '2020-11-04T08:08:43.298'

# %%
content[0]['identifier']
# Out:
# {'system': 'https://livehealth.in', 'value': None}

# %%
content[0]['type']
# Out:
# 'document'

# %%
content[0]['id']
# Out:
# 'DiagnosticReport-Livehealth (Bidirectional Outsourcing)-03 Jun 2020'

# %%
content[1]['entry']
# Out:
# [{'resource': {'telecom': [{'use': 'MOBILE',
#      'system': 'phone',
#      'value': '7845245142'}],
#    'meta': {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/Patient'],
#     'versionId': '1',
#     'lastUpdated': '2020-10-16T10:35:28Z'},
#    'name': [{'text': 'Testing 8'}],
#    'gender': 'male',
#    'resourceType': 'Patient',
#    'text': {'status': 'generated', 'div': 'Testing 8'},
#    'identifier': [{'type': {'coding': [{'code': '',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'display': 2625}]},
#      'system': '',
#      'value': ''}],
#    'id': 20778513,
#    'birthDate': None},
#   'fullUrl': 'Patient/1'},
#  {'resource': {'name': [{'text': 'Pratik'}],
#    'resourceType': 'Practitioner',
#    'text': {'status': 'generated', 'div': 'Pratik'},
#    'meta': {'profile': ['https://nrces.in/ndhm/fhir/r4/StructureDefinition/Practitioner'],
#     'versionId': '1',
#     'lastUpdated': '2020-11-04T08:08:43.345'},
# ...

# %%
content[1]['timestamp']
# Out:
# '2020-11-04T08:08:43.335'

# %%
# Out:
# dict_keys(['resourceType', 'timestamp', 'meta', 'entry', 'identifier', 'type', 'id'])
